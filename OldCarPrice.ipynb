# %% [markdown]
# 1. Data Loading and Initial Exploration

# %% [markdown]
# Displaying the first few rows of the dataset.

# %%
import pandas as pd
column_names = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", "body-style", "drive-wheels", "engine-location", "wheel-base", "length", "width", "height", "curb-weight", "engine-type", "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke", "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"]
df = pd.read_csv('imports-85.data.txt', names=column_names, sep=',')
df.to_csv('data.csv', index=False)

df.shape
# Out:
# (205, 26)

# %% [markdown]
# Checking for the presence of missing values.

# %%
import numpy as np
df.replace('?',np.nan,inplace=True )
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Describing the basic statistics of numerical features.

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2145.000000    97.000000           8.600000   19.000000    25.000000
# 50%    2414.000000   120.000000           9.000000   24.000000    30.000000
# 75%    2935.000000   141.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %% [markdown]
# 2. Handling Missing Data

# %% [markdown]
# Identify and handle missing data in the dataset.
#
# Identify columns with missing values.

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Handling these missing values, whether by imputation or removal.

# %%
# here we are converting the categorical one to numerical
convert = {"num-of-doors": {"four": 4, "two": 2}}
df.replace(convert, inplace=True) 
df
# Out:
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\2092271849.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(convert, inplace=True)
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#      num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0             2.0  convertible          rwd           front        88.6  ...
# 1             2.0  convertible          rwd           front        88.6  ...
# 2             2.0    hatchback          rwd           front        94.5  ...
# 3             4.0        sedan          fwd           front        99.8  ...
# 4             4.0        sedan          4wd           front        99.4  ...
# ..            ...          ...          ...             ...         ...  ...
# 200           4.0        sedan          rwd           front       109.1  ...
# 201           4.0        sedan          rwd           front       109.1  ...
# 202           4.0        sedan          rwd           front       109.1  ...
# 203           4.0        sedan          rwd           front       109.1  ...
# 204           4.0        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19    3.40              10.0        102
# 4            136         mpfi  3.19    3.40               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01    3.40              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
columns_with_missing = df.columns[df.isnull().any()]
columns_with_missing
# Out:
# Index(['normalized-losses', 'num-of-doors', 'bore', 'stroke', 'horsepower',
#        'peak-rpm', 'price'],
#       dtype='object')

# %%
df["normalized-losses"].fillna(df["normalized-losses"].astype('float').mean(), inplace=True)
df["bore"].fillna(df["bore"].astype('float').mean(), inplace=True)
df["num-of-doors"].fillna(df["num-of-doors"].astype('float').mean(), inplace=True)
df["stroke"].fillna(df["stroke"].astype('float').mean(), inplace=True)
df["horsepower"].fillna(df["horsepower"].astype('float').mean(), inplace=True)
df["peak-rpm"].fillna(df["peak-rpm"].astype('float').mean(), inplace=True)

df.dropna(subset = ['price'], axis = 0, inplace = True)
df.shape
# Out:
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\4137535744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["normalized-losses"].fillna(df["normalized-losses"].astype('float').mean(), inplace=True)
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\4137535744.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["bore"].fillna(df["bore"].astype('float').mean(), inplace=True)
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\4137535744.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["num-of-doors"].fillna(df["num-of-doors"].astype('float').mean(), inplace=True)
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\4137535744.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["stroke"].fillna(df["stroke"].astype('float').mean(), inplace=True)
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\4137535744.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["horsepower"].fillna(df["horsepower"].astype('float').mean(), inplace=True)
# C:\Users\BIONIC COMPUTER\AppData\Local\Temp\ipykernel_32836\4137535744.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["peak-rpm"].fillna(df["peak-rpm"].astype('float').mean(), inplace=True)
# (201, 26)

# %%
df.isnull().any()
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke               False
# compression-ratio    False
# horsepower           False
# peak-rpm             False
# city-mpg             False
# highway-mpg          False
# price                False
# dtype: bool

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors         float64
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# 3. Data Transformation and Encoding

# %% [markdown]
# Identify columns with categorical data that need to be transformed into a numeric format.
# Apply suitable encoding techniques (e.g., one-hot encoding or label encoding) to convert categorical data into numeric data.

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("float")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors         float64
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'body-style', 'drive-wheels',
#        'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system',
#        'horsepower'],
#       dtype='object')

# %%
df = pd.get_dummies(df, columns=categorical_columns)
df.head()
# Out:
#    symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 0          3              122.0           2.0        88.6   168.8   64.1
# 1          3              122.0           2.0        88.6   168.8   64.1
# 2          1              122.0           2.0        94.5   171.2   65.5
# 3          2              164.0           4.0        99.8   176.6   66.2
# 4          2              164.0           4.0        99.4   176.6   66.4
#
#    height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 0    48.8         2548          130  3.47  ...          False          False
# 1    48.8         2548          130  3.47  ...          False          False
# 2    52.4         2823          152  2.68  ...          False          False
# 3    54.3         2337          109  3.19  ...          False          False
# 4    54.3         2824          136  3.19  ...          False          False
#
#    horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    horsepower_94  horsepower_95  horsepower_97
# 0          False          False          False
# 1          False          False          False
# 2          False          False          False
# 3          False          False          False
# 4          False          False          False
#
# [5 rows x 132 columns]

# %% [markdown]
# 4. Outlier Detection and Treatment

# %% [markdown]
# Apply an outlier detection method (e.g., IQR or Z-score) to detect outliers.

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64'])
def detect_and_treat_outliers(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
    return outliers

# Detect and treat outliers for each numerical column
outliers_dict = {}
for column in numerical_columns.columns:
    outliers = detect_and_treat_outliers(df, column)
    outliers_dict[column] = outliers

# Display the outliers in table format
for column, outliers in outliers_dict.items():
    if not outliers.empty:
        print(f"Outliers in {column}:")
        print(outliers)
# Out:
# Outliers in normalized-losses:
#      symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 10           2              192.0           2.0       101.2   176.8   64.8
# 11           0              192.0           4.0       101.2   176.8   64.8
# 104          3              194.0           2.0        91.3   170.7   67.9
# 105          3              194.0           2.0        91.3   170.7   67.9
# 106          1              231.0           2.0        99.2   178.5   67.9
# 178          3              197.0           2.0       102.9   183.5   67.7
# 179          3              197.0           2.0       102.9   183.5   67.7
# 190          3              256.0           2.0        94.5   165.7   64.0
#
#      height  curb-weight  engine-size  bore  ...  horsepower_82  \
# 10     54.3         2395          108  3.50  ...          False
# 11     54.3         2395          108  3.50  ...          False
# 104    49.7         3071          181  3.43  ...          False
# 105    49.7         3139          181  3.43  ...          False
# 106    49.7         3139          181  3.43  ...          False
# 178    52.0         2976          171  3.27  ...          False
# 179    52.0         3016          171  3.27  ...          False
# 190    51.4         2221          109  3.19  ...          False
#
#      horsepower_84  horsepower_85  horsepower_86  horsepower_88  \
# 10           False          False          False          False
# 11           False          False          False          False
# 104          False          False          False          False
# 105          False          False          False          False
# 106          False          False          False          False
# 178          False          False          False          False
# 179          False          False          False          False
# 190          False          False          False          False
#
#      horsepower_90  horsepower_92  horsepower_94  horsepower_95  horsepower_97
# 10           False          False          False          False          False
# 11           False          False          False          False          False
# 104          False          False          False          False          False
# 105          False          False          False          False          False
# 106          False          False          False          False          False
# 178          False          False          False          False          False
# 179          False          False          False          False          False
# 190           True          False          False          False          False
#
# [8 rows x 132 columns]
# Outliers in wheel-base:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 70         -1               93.0           4.0       115.6   202.6   71.7
# 71         -1              122.0           4.0       115.6   202.6   71.7
# 73          0              122.0           4.0       120.9   208.1   71.7
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 70    56.3         3770          183  3.58  ...          False          False
# 71    56.5         3740          234  3.46  ...          False          False
# 73    56.7         3900          308  3.80  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 70          False          False          False          False          False
# 71          False          False          False          False          False
# 73          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 70          False          False          False
# 71          False          False          False
# 73          False          False          False
#
# [3 rows x 132 columns]
# Outliers in length:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 18          2              121.0           2.0        88.4   141.1   60.3
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 18    53.2         1488           61  2.91  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 18          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 18          False          False          False
#
# [1 rows x 132 columns]
# Outliers in width:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 6           1              158.0           4.0       105.8   192.7   71.4
# 7           1              122.0           4.0       105.8   192.7   71.4
# 8           1              158.0           4.0       105.8   192.7   71.4
# 17          0              122.0           4.0       110.0   197.0   70.9
# 18          2              121.0           2.0        88.4   141.1   60.3
# 49          0              122.0           2.0       102.0   191.7   70.6
# 70         -1               93.0           4.0       115.6   202.6   71.7
# 71         -1              122.0           4.0       115.6   202.6   71.7
# 72          3              142.0           2.0        96.6   180.3   70.5
# 73          0              122.0           4.0       120.9   208.1   71.7
# 74          1              122.0           2.0       112.0   199.2   72.0
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 6     55.7         2844          136  3.19  ...          False          False
# 7     55.7         2954          136  3.19  ...          False          False
# 8     55.9         3086          131  3.13  ...          False          False
# 17    56.3         3505          209  3.62  ...          False          False
# 18    53.2         1488           61  2.91  ...          False          False
# 49    47.8         3950          326  3.54  ...          False          False
# 70    56.3         3770          183  3.58  ...          False          False
# 71    56.5         3740          234  3.46  ...          False          False
# 72    50.8         3685          234  3.46  ...          False          False
# 73    56.7         3900          308  3.80  ...          False          False
# 74    55.4         3715          304  3.80  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 6           False          False          False          False          False
# 7           False          False          False          False          False
# 8           False          False          False          False          False
# 17          False          False          False          False          False
# 18          False          False          False          False          False
# 49          False          False          False          False          False
# 70          False          False          False          False          False
# 71          False          False          False          False          False
# 72          False          False          False          False          False
# 73          False          False          False          False          False
# 74          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 6           False          False          False
# 7           False          False          False
# 8           False          False          False
# 17          False          False          False
# 18          False          False          False
# 49          False          False          False
# 70          False          False          False
# 71          False          False          False
# 72          False          False          False
# 73          False          False          False
# 74          False          False          False
#
# [11 rows x 132 columns]
# Outliers in curb-weight:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 47          0              145.0           4.0       113.0   199.6   69.6
# 48          0              122.0           4.0       113.0   199.6   69.6
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 47    52.8         4066          258  3.63  ...          False          False
# 48    52.8         4066          258  3.63  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 47          False          False          False          False          False
# 48          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 47          False          False          False
# 48          False          False          False
#
# [2 rows x 132 columns]
# Outliers in engine-size:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 15          0              122.0           4.0       103.5   189.0   66.9
# 16          0              122.0           2.0       103.5   193.8   67.9
# 17          0              122.0           4.0       110.0   197.0   70.9
# 47          0              145.0           4.0       113.0   199.6   69.6
# 48          0              122.0           4.0       113.0   199.6   69.6
# 49          0              122.0           2.0       102.0   191.7   70.6
# 71         -1              122.0           4.0       115.6   202.6   71.7
# 72          3              142.0           2.0        96.6   180.3   70.5
# 73          0              122.0           4.0       120.9   208.1   71.7
# 74          1              122.0           2.0       112.0   199.2   72.0
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 15    55.7         3230          209  3.62  ...          False          False
# 16    53.7         3380          209  3.62  ...          False          False
# 17    56.3         3505          209  3.62  ...          False          False
# 47    52.8         4066          258  3.63  ...          False          False
# 48    52.8         4066          258  3.63  ...          False          False
# 49    47.8         3950          326  3.54  ...          False          False
# 71    56.5         3740          234  3.46  ...          False          False
# 72    50.8         3685          234  3.46  ...          False          False
# 73    56.7         3900          308  3.80  ...          False          False
# 74    55.4         3715          304  3.80  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 15          False          False          False          False          False
# 16          False          False          False          False          False
# 17          False          False          False          False          False
# 47          False          False          False          False          False
# 48          False          False          False          False          False
# 49          False          False          False          False          False
# 71          False          False          False          False          False
# 72          False          False          False          False          False
# 73          False          False          False          False          False
# 74          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 15          False          False          False
# 16          False          False          False
# 17          False          False          False
# 47          False          False          False
# 48          False          False          False
# 49          False          False          False
# 71          False          False          False
# 72          False          False          False
# 73          False          False          False
# 74          False          False          False
#
# [10 rows x 132 columns]
# Outliers in stroke:
#      symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 29           3              145.0           2.0        95.9   173.2   66.3
# 47           0              145.0           4.0       113.0   199.6   69.6
# 48           0              122.0           4.0       113.0   199.6   69.6
# 111          0              161.0           4.0       107.9   186.7   68.4
# 113          0              122.0           4.0       114.2   198.9   68.4
# 130          0              122.0           4.0        96.1   181.5   66.5
# 131          2              122.0           2.0        96.1   176.8   66.6
# 134          3              150.0           2.0        99.1   186.6   66.5
# 138          2               83.0           2.0        93.7   156.9   63.4
# 139          2               83.0           2.0        93.7   157.9   63.6
# 140          2               83.0           2.0        93.3   157.3   63.8
# 141          0              102.0           4.0        97.2   172.0   65.4
# 142          0              102.0           4.0        97.2   172.0   65.4
# 143          0              102.0           4.0        97.2   172.0   65.4
# 144          0              102.0           4.0        97.0   172.0   65.4
# 145          0              102.0           4.0        97.0   172.0   65.4
# 146          0               89.0           4.0        97.0   173.5   65.4
# 147          0               89.0           4.0        97.0   173.5   65.4
# 148          0               85.0           4.0        96.9   173.6   65.4
# 149          0               85.0           4.0        96.9   173.6   65.4
#
#      height  curb-weight  engine-size  bore  ...  horsepower_82  \
# 29     50.2         2811          156  3.60  ...          False
# 47     52.8         4066          258  3.63  ...          False
# 48     52.8         4066          258  3.63  ...          False
# 111    56.7         3075          120  3.46  ...          False
# 113    56.7         3285          120  3.46  ...          False
# 130    55.2         2579          132  3.46  ...          False
# 131    50.5         2460          132  3.46  ...          False
# 134    56.1         2707          121  2.54  ...          False
# 138    53.7         2050           97  3.62  ...          False
# 139    53.7         2120          108  3.62  ...          False
# 140    55.7         2240          108  3.62  ...          False
# 141    52.5         2145          108  3.62  ...           True
# 142    52.5         2190          108  3.62  ...           True
# 143    52.5         2340          108  3.62  ...          False
# 144    54.3         2385          108  3.62  ...           True
# 145    54.3         2510          108  3.62  ...          False
# 146    53.0         2290          108  3.62  ...           True
# 147    53.0         2455          108  3.62  ...          False
# 148    54.9         2420          108  3.62  ...           True
# 149    54.9         2650          108  3.62  ...          False
#
#      horsepower_84  horsepower_85  horsepower_86  horsepower_88  \
# 29           False          False          False          False
# 47           False          False          False          False
# 48           False          False          False          False
# 111          False          False          False          False
# 113          False          False          False          False
# 130          False          False          False          False
# 131          False          False          False          False
# 134          False          False          False          False
# 138          False          False          False          False
# 139          False          False          False          False
# 140          False          False          False          False
# 141          False          False          False          False
# 142          False          False          False          False
# 143          False          False          False          False
# 144          False          False          False          False
# 145          False          False          False          False
# 146          False          False          False          False
# 147          False          False          False          False
# 148          False          False          False          False
# 149          False          False          False          False
#
#      horsepower_90  horsepower_92  horsepower_94  horsepower_95  horsepower_97
# 29           False          False          False          False          False
# 47           False          False          False          False          False
# 48           False          False          False          False          False
# 111          False          False          False           True          False
# 113          False          False          False           True          False
# 130          False          False          False          False          False
# 131          False          False          False          False          False
# 134          False          False          False          False          False
# 138          False          False          False          False          False
# 139          False          False          False          False          False
# 140          False          False          False          False          False
# 141          False          False          False          False          False
# 142          False          False          False          False          False
# 143          False          False           True          False          False
# 144          False          False          False          False          False
# 145          False          False          False          False          False
# 146          False          False          False          False          False
# 147          False          False           True          False          False
# 148          False          False          False          False          False
# 149          False          False          False          False          False
#
# [20 rows x 132 columns]
# Outliers in compression-ratio:
#      symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 29           3              145.0      2.000000        95.9   173.2   66.3
# 49           0              122.0      2.000000       102.0   191.7   70.6
# 63           0              122.0      3.123153        98.8   177.8   66.5
# 66           0              122.0      4.000000       104.9   175.0   66.1
# 67          -1               93.0      4.000000       110.0   190.9   70.3
# 68          -1               93.0      4.000000       110.0   190.9   70.3
# 69           0               93.0      2.000000       106.7   187.5   70.3
# 70          -1               93.0      4.000000       115.6   202.6   71.7
# 82           3              122.0      2.000000        95.9   173.2   66.3
# 83           3              122.0      2.000000        95.9   173.2   66.3
# 84           3              122.0      2.000000        95.9   173.2   66.3
# 90           1              128.0      2.000000        94.5   165.3   63.8
# 108          0              161.0      4.000000       107.9   186.7   68.4
# 110          0              122.0      4.000000       114.2   198.9   68.4
# 112          0              161.0      4.000000       107.9   186.7   68.4
# 114          0              122.0      4.000000       114.2   198.9   68.4
# 116          0              161.0      4.000000       107.9   186.7   68.4
# 117          0              161.0      4.000000       108.0   186.7   68.3
# 124          3              122.0      2.000000        95.9   173.2   66.3
# 158          0               91.0      4.000000        95.7   166.3   64.4
# 159          0               91.0      4.000000        95.7   166.3   64.4
# 174         -1               65.0      4.000000       102.4   175.6   66.5
# 182          2              122.0      2.000000        97.3   171.7   65.5
# 184          2               94.0      4.000000        97.3   171.7   65.5
# 187          2               94.0      4.000000        97.3   171.7   65.5
# 192          0              122.0      4.000000       100.4   180.2   66.9
# 203         -1               95.0      4.000000       109.1   188.8   68.9
#
#      height  curb-weight  engine-size  bore  ...  horsepower_82  \
# 29     50.2         2811          156  3.60  ...          False
# 49     47.8         3950          326  3.54  ...          False
# 63     55.5         2443          122  3.39  ...          False
# 66     54.4         2700          134  3.43  ...          False
# 67     56.5         3515          183  3.58  ...          False
# 68     58.7         3750          183  3.58  ...          False
# 69     54.9         3495          183  3.58  ...          False
# 70     56.3         3770          183  3.58  ...          False
# 82     50.2         2833          156  3.58  ...          False
# 83     50.2         2921          156  3.59  ...          False
# 84     50.2         2926          156  3.59  ...          False
# 90     54.5         2017          103  2.99  ...          False
# 108    56.7         3197          152  3.70  ...          False
# 110    58.7         3430          152  3.70  ...          False
# 112    56.7         3252          152  3.70  ...          False
# 114    58.7         3485          152  3.70  ...          False
# 116    56.7         3252          152  3.70  ...          False
# 117    56.0         3130          134  3.61  ...          False
# 124    50.2         2818          156  3.59  ...          False
# 158    53.0         2275          110  3.27  ...          False
# 159    52.8         2275          110  3.27  ...          False
# 174    54.9         2480          110  3.27  ...          False
# 182    55.7         2261           97  3.01  ...          False
# 184    55.7         2264           97  3.01  ...          False
# 187    55.7         2319           97  3.01  ...          False
# 192    55.1         2579           97  3.01  ...          False
# 203    55.5         3217          145  3.01  ...          False
#
#      horsepower_84  horsepower_85  horsepower_86  horsepower_88  \
# 29           False          False          False          False
# 49           False          False          False          False
# 63           False          False          False          False
# 66           False          False          False          False
# 67           False          False          False          False
# 68           False          False          False          False
# 69           False          False          False          False
# 70           False          False          False          False
# 82           False          False          False          False
# 83           False          False          False          False
# 84           False          False          False          False
# 90           False          False          False          False
# 108          False          False          False          False
# 110          False          False          False          False
# 112          False          False          False          False
# 114          False          False          False          False
# 116          False          False          False          False
# 117          False          False          False          False
# 124          False          False          False          False
# 158          False          False          False          False
# 159          False          False          False          False
# 174          False          False          False          False
# 182          False          False          False          False
# 184          False          False          False          False
# 187          False          False          False          False
# 192          False          False          False          False
# 203          False          False          False          False
#
#      horsepower_90  horsepower_92  horsepower_94  horsepower_95  horsepower_97
# 29           False          False          False          False          False
# 49           False          False          False          False          False
# 63           False          False          False          False          False
# 66           False          False          False          False          False
# 67           False          False          False          False          False
# 68           False          False          False          False          False
# 69           False          False          False          False          False
# 70           False          False          False          False          False
# 82           False          False          False          False          False
# 83           False          False          False          False          False
# 84           False          False          False          False          False
# 90           False          False          False          False          False
# 108          False          False          False           True          False
# 110          False          False          False           True          False
# 112          False          False          False           True          False
# 114          False          False          False           True          False
# 116          False          False          False           True          False
# 117          False          False          False          False          False
# 124          False          False          False          False          False
# 158          False          False          False          False          False
# 159          False          False          False          False          False
# 174          False          False          False          False          False
# 182          False          False          False          False          False
# 184          False          False          False          False          False
# 187          False          False          False          False          False
# 192          False          False          False          False          False
# 203          False          False          False          False          False
#
# [27 rows x 132 columns]
# Outliers in peak-rpm:
#      symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 165          1              168.0           2.0        94.5   168.7   64.0
# 166          1              168.0           2.0        94.5   168.7   64.0
#
#      height  curb-weight  engine-size  bore  ...  horsepower_82  \
# 165    52.6         2265           98  3.24  ...          False
# 166    52.6         2300           98  3.24  ...          False
#
#      horsepower_84  horsepower_85  horsepower_86  horsepower_88  \
# 165          False          False          False          False
# 166          False          False          False          False
#
#      horsepower_90  horsepower_92  horsepower_94  horsepower_95  horsepower_97
# 165          False          False          False          False          False
# 166          False          False          False          False          False
#
# [2 rows x 132 columns]
# Outliers in city-mpg:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 18          2              121.0           2.0        88.4   141.1   60.3
# 30          2              137.0           2.0        86.6   144.6   63.9
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 18    53.2         1488           61  2.91  ...          False          False
# 30    50.8         1713           92  2.91  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 18          False          False          False          False          False
# 30          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 18          False          False          False
# 30          False          False          False
#
# [2 rows x 132 columns]
# Outliers in highway-mpg:
#     symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 18          2              121.0           2.0        88.4   141.1   60.3
# 30          2              137.0           2.0        86.6   144.6   63.9
# 90          1              128.0           2.0        94.5   165.3   63.8
#
#     height  curb-weight  engine-size  bore  ...  horsepower_82  horsepower_84  \
# 18    53.2         1488           61  2.91  ...          False          False
# 30    50.8         1713           92  2.91  ...          False          False
# 90    54.5         2017          103  2.99  ...          False          False
#
#     horsepower_85  horsepower_86  horsepower_88  horsepower_90  horsepower_92  \
# 18          False          False          False          False          False
# 30          False          False          False          False          False
# 90          False          False          False          False          False
#
#     horsepower_94  horsepower_95  horsepower_97
# 18          False          False          False
# 30          False          False          False
# 90          False          False          False
#
# [3 rows x 132 columns]
# Outliers in price:
#      symboling  normalized-losses  num-of-doors  wheel-base  length  width  \
# 15           0              122.0           4.0       103.5   189.0   66.9
# 16           0              122.0           2.0       103.5   193.8   67.9
# 17           0              122.0           4.0       110.0   197.0   70.9
# 47           0              145.0           4.0       113.0   199.6   69.6
# 48           0              122.0           4.0       113.0   199.6   69.6
# 49           0              122.0           2.0       102.0   191.7   70.6
# 70          -1               93.0           4.0       115.6   202.6   71.7
# 71          -1              122.0           4.0       115.6   202.6   71.7
# 72           3              142.0           2.0        96.6   180.3   70.5
# 73           0              122.0           4.0       120.9   208.1   71.7
# 74           1              122.0           2.0       112.0   199.2   72.0
# 126          3              122.0           2.0        89.5   168.9   65.0
# 127          3              122.0           2.0        89.5   168.9   65.0
# 128          3              122.0           2.0        89.5   168.9   65.0
#
#      height  curb-weight  engine-size  bore  ...  horsepower_82  \
# 15     55.7         3230          209  3.62  ...          False
# 16     53.7         3380          209  3.62  ...          False
# 17     56.3         3505          209  3.62  ...          False
# 47     52.8         4066          258  3.63  ...          False
# 48     52.8         4066          258  3.63  ...          False
# 49     47.8         3950          326  3.54  ...          False
# 70     56.3         3770          183  3.58  ...          False
# 71     56.5         3740          234  3.46  ...          False
# 72     50.8         3685          234  3.46  ...          False
# 73     56.7         3900          308  3.80  ...          False
# 74     55.4         3715          304  3.80  ...          False
# 126    51.6         2756          194  3.74  ...          False
# 127    51.6         2756          194  3.74  ...          False
# 128    51.6         2800          194  3.74  ...          False
#
#      horsepower_84  horsepower_85  horsepower_86  horsepower_88  \
# 15           False          False          False          False
# 16           False          False          False          False
# 17           False          False          False          False
# 47           False          False          False          False
# 48           False          False          False          False
# 49           False          False          False          False
# 70           False          False          False          False
# 71           False          False          False          False
# 72           False          False          False          False
# 73           False          False          False          False
# 74           False          False          False          False
# 126          False          False          False          False
# 127          False          False          False          False
# 128          False          False          False          False
#
#      horsepower_90  horsepower_92  horsepower_94  horsepower_95  horsepower_97
# 15           False          False          False          False          False
# 16           False          False          False          False          False
# 17           False          False          False          False          False
# 47           False          False          False          False          False
# 48           False          False          False          False          False
# 49           False          False          False          False          False
# 70           False          False          False          False          False
# 71           False          False          False          False          False
# 72           False          False          False          False          False
# 73           False          False          False          False          False
# 74           False          False          False          False          False
# 126          False          False          False          False          False
# 127          False          False          False          False          False
# 128          False          False          False          False          False
#
# [14 rows x 132 columns]

# %% [markdown]
# 5. Feature Scaling

# %% [markdown]
# Feature scaling to the numerical features to ensure that all features are on a similar scale.

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
data_normalized = min_max_scaler.fit_transform(numerical_columns)
data_normalized = pd.DataFrame(data_normalized, columns=numerical_columns.columns)
print(data_normalized)
# Out:
#      symboling  normalized-losses  num-of-doors  wheel-base    length  \
# 0          1.0           0.298429           0.0    0.058309  0.413433
# 1          1.0           0.298429           0.0    0.058309  0.413433
# 2          0.6           0.298429           0.0    0.230321  0.449254
# 3          0.8           0.518325           1.0    0.384840  0.529851
# 4          0.8           0.518325           1.0    0.373178  0.529851
# ..         ...                ...           ...         ...       ...
# 196        0.2           0.157068           1.0    0.655977  0.711940
# 197        0.2           0.157068           1.0    0.655977  0.711940
# 198        0.2           0.157068           1.0    0.655977  0.711940
# 199        0.2           0.157068           1.0    0.655977  0.711940
# 200        0.2           0.157068           1.0    0.655977  0.711940
#
#         width    height  curb-weight  engine-size      bore    stroke  \
# 0    0.324786  0.083333     0.411171     0.260377  0.664286  0.290476
# 1    0.324786  0.083333     0.411171     0.260377  0.664286  0.290476
# 2    0.444444  0.383333     0.517843     0.343396  0.100000  0.666667
# 3    0.504274  0.541667     0.329325     0.181132  0.464286  0.633333
# 4    0.521368  0.541667     0.518231     0.283019  0.464286  0.633333
# ..        ...       ...          ...          ...       ...       ...
# 196  0.735043  0.641667     0.567882     0.301887  0.885714  0.514286
# 197  0.726496  0.641667     0.605508     0.301887  0.885714  0.514286
# 198  0.735043  0.641667     0.591156     0.422642  0.742857  0.380952
# 199  0.735043  0.641667     0.670675     0.316981  0.335714  0.633333
# 200  0.735043  0.641667     0.610551     0.301887  0.885714  0.514286
#
#      compression-ratio  peak-rpm  city-mpg  highway-mpg     price
# 0              0.12500  0.346939  0.222222     0.289474  0.207959
# 1              0.12500  0.346939  0.222222     0.289474  0.282558
# 2              0.12500  0.346939  0.166667     0.263158  0.282558
# 3              0.18750  0.551020  0.305556     0.368421  0.219254
# 4              0.06250  0.551020  0.138889     0.157895  0.306142
# ..                 ...       ...       ...          ...       ...
# 196            0.15625  0.510204  0.277778     0.315789  0.291123
# 197            0.10625  0.469388  0.166667     0.236842  0.345738
# 198            0.11250  0.551020  0.138889     0.184211  0.406311
# 199            1.00000  0.265306  0.361111     0.289474  0.430763
# 200            0.15625  0.510204  0.166667     0.236842  0.434611
#
# [201 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(numerical_columns)
print(df_scaled)
# Out:
# [[ 1.72504964  0.         -1.15189655 ... -0.65224901 -0.54228772
#    0.03631396]
#  [ 1.72504964  0.         -1.15189655 ... -0.65224901 -0.54228772
#    0.41538505]
#  [ 0.1271926   0.         -1.15189655 ... -0.96439676 -0.689386
#    0.41538505]
#  ...
#  [-1.47066444 -0.84595589  0.87688728 ... -1.12047063 -1.13068086
#    1.04422678]
#  [-1.47066444 -0.84595589  0.87688728 ...  0.12812034 -0.54228772
#    1.16848137]
#  [-1.47066444 -0.84595589  0.87688728 ... -0.96439676 -0.83648429
#    1.18803412]]
